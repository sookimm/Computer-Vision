# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img_path = r"Cat.jpg"
 
image = cv2.imread(img_path)
 
cv2.imshow("Rectangle on Image", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# flattened
image.ravel()
# Out:
# array([179, 208, 217, ..., 198, 214, 226], shape=(3148800,), dtype=uint8)

# %%
image.ravel().shape
# Out:
# (3148800,)

# %%
image.ravel().size
# Out:
# 3148800

# %%
# image should be flattened e.g., using ravel()
plt.hist(image.ravel(), bins=256, range = [0,255])
plt.show()

# %%
colors = ('b', 'g', 'r')
 
img_ravel = [image[:, :, 0].ravel(), image[:, :, 1].ravel(), image[:,:, 2].ravel()] 
plt.hist(img_ravel, color= colors, label= colors)
plt.legend()
plt.show()

# %%
colors = ('b', 'g', 'r')
 
img_ravel = [image[:, :, 0].ravel(), image[:, :, 1].ravel(), image[:,:, 2].ravel()] 
plt.hist(img_ravel, color= colors, label= colors, bins= 256, range= [0,256])
plt.title('Histogram')
plt.xlabel('pixel intensity')
plt.ylabel('count')
plt.legend()
plt.show()

# %%
# Plot of all Channel using cv2.calcHist() Function

colors = ('b', 'g', 'r')      
plt.figure(figsize=(16, 9))

for i, color in enumerate(colors):
    histogram = cv2.calcHist([image], [i], None, [256], [0, 256])
    plt.plot(histogram, color= color)
plt.show()

# %%
l1 = ["eat", "sleep", "repeat"]

for s in enumerate(l1):
    print (s)
# Out:
# (0, 'eat')
# (1, 'sleep')
# (2, 'repeat')

# %%
# getting desired output from tuple
for count, element in enumerate(l1):
    print(count)
    print(element)
# Out:
# 0
# eat
# 1
# sleep
# 2
# repeat
